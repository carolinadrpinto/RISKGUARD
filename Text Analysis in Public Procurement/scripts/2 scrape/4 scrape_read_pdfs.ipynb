# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import re
import csv
from typing import Optional, List, Dict, Any
import pandas as pd

# from utilities.funcoes_scrape import

# %%
from pypdf import PdfReader

# %%
ROOT_DIR = Path("../../docs_pecas")   # <-- change this


# 🔎 Flexible match for "especificações técnicas"
ESPEC_TEC_RX = re.compile(
    r"especifica(?:c|ç)(?:a|ã|o|õ)?es?\s*t[eé]cnic(?:a|as|o|os)?",
    re.IGNORECASE
)


_CADERNO_RX = re.compile(
    r"(?:"
    r"(?<![A-Za-z0-9])caderno(?:s)?(?![A-Za-z0-9])"                        # standalone "caderno(s)"
    r"|"                                                                    # or
    r"(?<![A-Za-z0-9])caderno(?:s)?(?:[\s_]+(?:de[\s_]+)?encargo(?:s)?)(?![A-Za-z0-9])"  # caderno de encargos
    r"|"                                                                    # or CE between underscores / edges
    r"(?:(?:^|_)ce(?:_|$))"
    r")",
    re.IGNORECASE

)

# Matches:
# - "programa" or "programas" (standalone)
# - optional tail: "do procedimento" or "do concurso"
_PROGRAMA_RX = re.compile(
    r"(?<![A-Za-z0-9])programa(?:s)?(?:[\s_]+(?:do[\s_]+)?(?:procedimento|concurso))?(?![A-Za-z0-9])"
)

# %%
def is_identifier_folder(p: Path) -> bool:
    return p.is_dir() and p.name.isdigit()

# %%
def find_matching_pdfs(folder: Path, rx: re.Pattern) -> List[Path]:
    return sorted(
        [
            f for f in folder.iterdir()
            if f.is_file() and f.suffix.lower() == ".pdf" and rx.search(f.name)
        ],
        key=lambda x: x.name.lower()
    )

# %%
def count_pdf_pages(pdf_path: Path) -> Optional[int]:
    try:
        reader = PdfReader(str(pdf_path))
        return len(reader.pages)
    except Exception:
        return None

# %%
def pdf_contains_pattern(pdf_path: Path, rx: re.Pattern) -> Optional[bool]:
    """
    True  -> pattern found
    False -> pattern not found
    None  -> text extraction failed (scanned PDF)
    """
    try:
        reader = PdfReader(str(pdf_path))
        for page in reader.pages:
            text = page.extract_text() or ""
            if rx.search(text):
                return True
        return False
    except Exception:
        return None

# %%
results: List[Dict[str, Any]] = []

id_folders = sorted(
    [p for p in ROOT_DIR.iterdir() if is_identifier_folder(p)],
    key=lambda x: int(x.name)
)

for folder in id_folders:
    identifier = folder.name

    programa_pdfs = find_matching_pdfs(folder, _PROGRAMA_RX)
    caderno_pdfs = find_matching_pdfs(folder, _CADERNO_RX)

    programa_pdf = programa_pdfs[0] if programa_pdfs else None
    caderno_pdf = caderno_pdfs[0] if caderno_pdfs else None

    programa_pages = count_pdf_pages(programa_pdf) if programa_pdf else None
    caderno_pages = count_pdf_pages(caderno_pdf) if caderno_pdf else None

    espec_found = None
    if caderno_pdf:
        espec_found = pdf_contains_pattern(caderno_pdf, ESPEC_TEC_RX)

    results.append({
        "identifier": identifier,

        "programa_pdf": programa_pdf.name if programa_pdf else "",
        "programa_pages": programa_pages,
        "programa_match_count": len(programa_pdfs),

        "caderno_pdf": caderno_pdf.name if caderno_pdf else "",
        "caderno_pages": caderno_pages,
        "caderno_match_count": len(caderno_pdfs),

        "caderno_has_especificacoes_tecnicas":
            "" if not caderno_pdf else
            ("EXTRACTION_FAILED" if espec_found is None else espec_found)
    })
# Out:
# Multiple definitions in dictionary at byte 0x1ecf79 for key /AcroForm
# Multiple definitions in dictionary at byte 0x1ecf79 for key /AcroForm
# parsing for Object Streams
# parsing for Object Streams
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 18 65536 (offset 0)
# Ignoring wrong pointing object 31 65536 (offset 0)
# Ignoring wrong pointing object 37 65536 (offset 0)
# Ignoring wrong pointing object 43 65536 (offset 0)
# Ignoring wrong pointing object 49 65536 (offset 0)
# Ignoring wrong pointing object 55 65536 (offset 0)
# Ignoring wrong pointing object 61 65536 (offset 0)
# Ignoring wrong pointing object 67 65536 (offset 0)
# Ignoring wrong pointing object 73 65536 (offset 0)
# Ignoring wrong pointing object 79 65536 (offset 0)
# Ignoring wrong pointing object 85 65536 (offset 0)
# Ignoring wrong pointing object 91 65536 (offset 0)
# Ignoring wrong pointing object 97 65536 (offset 0)
# Ignoring wrong pointing object 103 65536 (offset 0)
# Ignoring wrong pointing object 109 65536 (offset 0)
# Ignoring wrong pointing object 115 65536 (offset 0)
# Ignoring wrong pointing object 121 65536 (offset 0)
# Ignoring wrong pointing object 174 65536 (offset 0)
# Ignoring wrong pointing object 186 65536 (offset 0)
# Ignoring wrong pointing object 342 65536 (offset 0)
# Ignoring wrong pointing object 427 65536 (offset 0)
# Ignoring wrong pointing object 505 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 708 65536 (offset 0)
# Ignoring wrong pointing object 785 65536 (offset 0)
# Ignoring wrong pointing object 866 65536 (offset 0)
# Ignoring wrong pointing object 928 65536 (offset 0)
# Ignoring wrong pointing object 1034 65536 (offset 0)
# Ignoring wrong pointing object 1149 65536 (offset 0)
# Ignoring wrong pointing object 1261 65536 (offset 0)
# Ignoring wrong pointing object 1341 65536 (offset 0)
# Ignoring wrong pointing object 1431 65536 (offset 0)
# Ignoring wrong pointing object 1531 65536 (offset 0)
# Ignoring wrong pointing object 1606 65536 (offset 0)
# Ignoring wrong pointing object 1708 65536 (offset 0)
# Ignoring wrong pointing object 1834 65536 (offset 0)
# Ignoring wrong pointing object 1922 65536 (offset 0)
# Ignoring wrong pointing object 2006 65536 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 18 65536 (offset 0)
# Ignoring wrong pointing object 31 65536 (offset 0)
# Ignoring wrong pointing object 37 65536 (offset 0)
# Ignoring wrong pointing object 43 65536 (offset 0)
# Ignoring wrong pointing object 49 65536 (offset 0)
# Ignoring wrong pointing object 55 65536 (offset 0)
# Ignoring wrong pointing object 61 65536 (offset 0)
# Ignoring wrong pointing object 67 65536 (offset 0)
# Ignoring wrong pointing object 73 65536 (offset 0)
# Ignoring wrong pointing object 79 65536 (offset 0)
# Ignoring wrong pointing object 85 65536 (offset 0)
# Ignoring wrong pointing object 91 65536 (offset 0)
# Ignoring wrong pointing object 97 65536 (offset 0)
# Ignoring wrong pointing object 103 65536 (offset 0)
# Ignoring wrong pointing object 109 65536 (offset 0)
# Ignoring wrong pointing object 115 65536 (offset 0)
# Ignoring wrong pointing object 121 65536 (offset 0)
# Ignoring wrong pointing object 174 65536 (offset 0)
# Ignoring wrong pointing object 186 65536 (offset 0)
# Ignoring wrong pointing object 342 65536 (offset 0)
# Ignoring wrong pointing object 427 65536 (offset 0)
# Ignoring wrong pointing object 505 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 708 65536 (offset 0)
# Ignoring wrong pointing object 785 65536 (offset 0)
# Ignoring wrong pointing object 866 65536 (offset 0)
# Ignoring wrong pointing object 928 65536 (offset 0)
# Ignoring wrong pointing object 1034 65536 (offset 0)
# Ignoring wrong pointing object 1149 65536 (offset 0)
# Ignoring wrong pointing object 1261 65536 (offset 0)
# Ignoring wrong pointing object 1341 65536 (offset 0)
# Ignoring wrong pointing object 1431 65536 (offset 0)
# Ignoring wrong pointing object 1531 65536 (offset 0)
# Ignoring wrong pointing object 1606 65536 (offset 0)
# Ignoring wrong pointing object 1708 65536 (offset 0)
# Ignoring wrong pointing object 1834 65536 (offset 0)
# Ignoring wrong pointing object 1922 65536 (offset 0)
# Ignoring wrong pointing object 2006 65536 (offset 0)
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 23 65536 (offset 0)
# Ignoring wrong pointing object 39 65536 (offset 0)
# Ignoring wrong pointing object 57 65536 (offset 0)
# Ignoring wrong pointing object 69 65536 (offset 0)
# Ignoring wrong pointing object 85 65536 (offset 0)
# Ignoring wrong pointing object 99 65536 (offset 0)
# Ignoring wrong pointing object 115 65536 (offset 0)
# Ignoring wrong pointing object 131 65536 (offset 0)
# Ignoring wrong pointing object 148 65536 (offset 0)
# Ignoring wrong pointing object 164 65536 (offset 0)
# Ignoring wrong pointing object 176 65536 (offset 0)
# Ignoring wrong pointing object 190 65536 (offset 0)
# Ignoring wrong pointing object 208 65536 (offset 0)
# Ignoring wrong pointing object 226 65536 (offset 0)
# Ignoring wrong pointing object 244 65536 (offset 0)
# Ignoring wrong pointing object 256 65536 (offset 0)
# Ignoring wrong pointing object 268 65536 (offset 0)
# Ignoring wrong pointing object 280 65536 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 23 65536 (offset 0)
# Ignoring wrong pointing object 39 65536 (offset 0)
# Ignoring wrong pointing object 57 65536 (offset 0)
# Ignoring wrong pointing object 69 65536 (offset 0)
# Ignoring wrong pointing object 85 65536 (offset 0)
# Ignoring wrong pointing object 99 65536 (offset 0)
# Ignoring wrong pointing object 115 65536 (offset 0)
# Ignoring wrong pointing object 131 65536 (offset 0)
# Ignoring wrong pointing object 148 65536 (offset 0)
# Ignoring wrong pointing object 164 65536 (offset 0)
# Ignoring wrong pointing object 176 65536 (offset 0)
# Ignoring wrong pointing object 190 65536 (offset 0)
# Ignoring wrong pointing object 208 65536 (offset 0)
# Ignoring wrong pointing object 226 65536 (offset 0)
# Ignoring wrong pointing object 244 65536 (offset 0)
# Ignoring wrong pointing object 256 65536 (offset 0)
# Ignoring wrong pointing object 268 65536 (offset 0)
# Ignoring wrong pointing object 280 65536 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 23 65536 (offset 0)
# Ignoring wrong pointing object 35 65536 (offset 0)
# Ignoring wrong pointing object 39 65536 (offset 0)
# Ignoring wrong pointing object 43 65536 (offset 0)
# Ignoring wrong pointing object 47 65536 (offset 0)
# Ignoring wrong pointing object 51 65536 (offset 0)
# Ignoring wrong pointing object 55 65536 (offset 0)
# Ignoring wrong pointing object 59 65536 (offset 0)
# Ignoring wrong pointing object 63 65536 (offset 0)
# Ignoring wrong pointing object 75 65536 (offset 0)
# Ignoring wrong pointing object 79 65536 (offset 0)
# Ignoring wrong pointing object 83 65536 (offset 0)
# Ignoring wrong pointing object 87 65536 (offset 0)
# Ignoring wrong pointing object 91 65536 (offset 0)
# Ignoring wrong pointing object 95 65536 (offset 0)
# Ignoring wrong pointing object 99 65536 (offset 0)
# Ignoring wrong pointing object 103 65536 (offset 0)
# Ignoring wrong pointing object 107 65536 (offset 0)
# Ignoring wrong pointing object 119 65536 (offset 0)
# Ignoring wrong pointing object 123 65536 (offset 0)
# Ignoring wrong pointing object 127 65536 (offset 0)
# Ignoring wrong pointing object 131 65536 (offset 0)
# Ignoring wrong pointing object 135 65536 (offset 0)
# Ignoring wrong pointing object 139 65536 (offset 0)
# Ignoring wrong pointing object 143 65536 (offset 0)
# Ignoring wrong pointing object 147 65536 (offset 0)
# Ignoring wrong pointing object 151 65536 (offset 0)
# Ignoring wrong pointing object 155 65536 (offset 0)
# Ignoring wrong pointing object 167 65536 (offset 0)
# Ignoring wrong pointing object 171 65536 (offset 0)
# Ignoring wrong pointing object 175 65536 (offset 0)
# Ignoring wrong pointing object 179 65536 (offset 0)
# Ignoring wrong pointing object 183 65536 (offset 0)
# Ignoring wrong pointing object 187 65536 (offset 0)
# Ignoring wrong pointing object 191 65536 (offset 0)
# Ignoring wrong pointing object 195 65536 (offset 0)
# Ignoring wrong pointing object 199 65536 (offset 0)
# Ignoring wrong pointing object 203 65536 (offset 0)
# Ignoring wrong pointing object 207 65536 (offset 0)
# Ignoring wrong pointing object 211 65536 (offset 0)
# Ignoring wrong pointing object 215 65536 (offset 0)
# Ignoring wrong pointing object 219 65536 (offset 0)
# Ignoring wrong pointing object 223 65536 (offset 0)
# Ignoring wrong pointing object 227 65536 (offset 0)
# Ignoring wrong pointing object 247 65536 (offset 0)
# Ignoring wrong pointing object 259 65536 (offset 0)
# Ignoring wrong pointing object 263 65536 (offset 0)
# Ignoring wrong pointing object 267 65536 (offset 0)
# Ignoring wrong pointing object 280 65536 (offset 0)
# Ignoring wrong pointing object 284 65536 (offset 0)
# Ignoring wrong pointing object 296 65536 (offset 0)
# Ignoring wrong pointing object 299 65536 (offset 0)
# Ignoring wrong pointing object 302 65536 (offset 0)
# Ignoring wrong pointing object 305 65536 (offset 0)
# Ignoring wrong pointing object 310 65536 (offset 0)
# Ignoring wrong pointing object 315 65536 (offset 0)
# Ignoring wrong pointing object 320 65536 (offset 0)
# Ignoring wrong pointing object 323 65536 (offset 0)
# Ignoring wrong pointing object 326 65536 (offset 0)
# Ignoring wrong pointing object 329 65536 (offset 0)
# Ignoring wrong pointing object 332 65536 (offset 0)
# Ignoring wrong pointing object 348 65536 (offset 0)
# Ignoring wrong pointing object 385 65536 (offset 0)
# Ignoring wrong pointing object 421 65536 (offset 0)
# Ignoring wrong pointing object 443 65536 (offset 0)
# Ignoring wrong pointing object 447 65536 (offset 0)
# Ignoring wrong pointing object 451 65536 (offset 0)
# Ignoring wrong pointing object 553 65536 (offset 0)
# Ignoring wrong pointing object 969 65536 (offset 0)
# Ignoring wrong pointing object 1280 65536 (offset 0)
# Ignoring wrong pointing object 1695 65536 (offset 0)
# Ignoring wrong pointing object 2190 65536 (offset 0)
# Ignoring wrong pointing object 2546 65536 (offset 0)
# Ignoring wrong pointing object 2763 65536 (offset 0)
# Ignoring wrong pointing object 2766 65536 (offset 0)
# Ignoring wrong pointing object 2773 65536 (offset 0)
# Ignoring wrong pointing object 2780 65536 (offset 0)
# Ignoring wrong pointing object 2787 65536 (offset 0)
# Ignoring wrong pointing object 2790 65536 (offset 0)
# Ignoring wrong pointing object 2793 65536 (offset 0)
# Ignoring wrong pointing object 2798 65536 (offset 0)
# Ignoring wrong pointing object 2801 65536 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 23 65536 (offset 0)
# Ignoring wrong pointing object 35 65536 (offset 0)
# Ignoring wrong pointing object 39 65536 (offset 0)
# Ignoring wrong pointing object 43 65536 (offset 0)
# Ignoring wrong pointing object 47 65536 (offset 0)
# Ignoring wrong pointing object 51 65536 (offset 0)
# Ignoring wrong pointing object 55 65536 (offset 0)
# Ignoring wrong pointing object 59 65536 (offset 0)
# Ignoring wrong pointing object 63 65536 (offset 0)
# Ignoring wrong pointing object 75 65536 (offset 0)
# Ignoring wrong pointing object 79 65536 (offset 0)
# Ignoring wrong pointing object 83 65536 (offset 0)
# Ignoring wrong pointing object 87 65536 (offset 0)
# Ignoring wrong pointing object 91 65536 (offset 0)
# Ignoring wrong pointing object 95 65536 (offset 0)
# Ignoring wrong pointing object 99 65536 (offset 0)
# Ignoring wrong pointing object 103 65536 (offset 0)
# Ignoring wrong pointing object 107 65536 (offset 0)
# Ignoring wrong pointing object 119 65536 (offset 0)
# Ignoring wrong pointing object 123 65536 (offset 0)
# Ignoring wrong pointing object 127 65536 (offset 0)
# Ignoring wrong pointing object 131 65536 (offset 0)
# Ignoring wrong pointing object 135 65536 (offset 0)
# Ignoring wrong pointing object 139 65536 (offset 0)
# Ignoring wrong pointing object 143 65536 (offset 0)
# Ignoring wrong pointing object 147 65536 (offset 0)
# Ignoring wrong pointing object 151 65536 (offset 0)
# Ignoring wrong pointing object 155 65536 (offset 0)
# Ignoring wrong pointing object 167 65536 (offset 0)
# Ignoring wrong pointing object 171 65536 (offset 0)
# Ignoring wrong pointing object 175 65536 (offset 0)
# Ignoring wrong pointing object 179 65536 (offset 0)
# Ignoring wrong pointing object 183 65536 (offset 0)
# Ignoring wrong pointing object 187 65536 (offset 0)
# Ignoring wrong pointing object 191 65536 (offset 0)
# Ignoring wrong pointing object 195 65536 (offset 0)
# Ignoring wrong pointing object 199 65536 (offset 0)
# Ignoring wrong pointing object 203 65536 (offset 0)
# Ignoring wrong pointing object 207 65536 (offset 0)
# Ignoring wrong pointing object 211 65536 (offset 0)
# Ignoring wrong pointing object 215 65536 (offset 0)
# Ignoring wrong pointing object 219 65536 (offset 0)
# Ignoring wrong pointing object 223 65536 (offset 0)
# Ignoring wrong pointing object 227 65536 (offset 0)
# Ignoring wrong pointing object 247 65536 (offset 0)
# Ignoring wrong pointing object 259 65536 (offset 0)
# Ignoring wrong pointing object 263 65536 (offset 0)
# Ignoring wrong pointing object 267 65536 (offset 0)
# Ignoring wrong pointing object 280 65536 (offset 0)
# Ignoring wrong pointing object 284 65536 (offset 0)
# Ignoring wrong pointing object 296 65536 (offset 0)
# Ignoring wrong pointing object 299 65536 (offset 0)
# Ignoring wrong pointing object 302 65536 (offset 0)
# Ignoring wrong pointing object 305 65536 (offset 0)
# Ignoring wrong pointing object 310 65536 (offset 0)
# Ignoring wrong pointing object 315 65536 (offset 0)
# Ignoring wrong pointing object 320 65536 (offset 0)
# Ignoring wrong pointing object 323 65536 (offset 0)
# Ignoring wrong pointing object 326 65536 (offset 0)
# Ignoring wrong pointing object 329 65536 (offset 0)
# Ignoring wrong pointing object 332 65536 (offset 0)
# Ignoring wrong pointing object 348 65536 (offset 0)
# Ignoring wrong pointing object 385 65536 (offset 0)
# Ignoring wrong pointing object 421 65536 (offset 0)
# Ignoring wrong pointing object 443 65536 (offset 0)
# Ignoring wrong pointing object 447 65536 (offset 0)
# Ignoring wrong pointing object 451 65536 (offset 0)
# Ignoring wrong pointing object 553 65536 (offset 0)
# Ignoring wrong pointing object 969 65536 (offset 0)
# Ignoring wrong pointing object 1280 65536 (offset 0)
# Ignoring wrong pointing object 1695 65536 (offset 0)
# Ignoring wrong pointing object 2190 65536 (offset 0)
# Ignoring wrong pointing object 2546 65536 (offset 0)
# Ignoring wrong pointing object 2763 65536 (offset 0)
# Ignoring wrong pointing object 2766 65536 (offset 0)
# Ignoring wrong pointing object 2773 65536 (offset 0)
# Ignoring wrong pointing object 2780 65536 (offset 0)
# Ignoring wrong pointing object 2787 65536 (offset 0)
# Ignoring wrong pointing object 2790 65536 (offset 0)
# Ignoring wrong pointing object 2793 65536 (offset 0)
# Ignoring wrong pointing object 2798 65536 (offset 0)
# Ignoring wrong pointing object 2801 65536 (offset 0)
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# parsing for Object Streams
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# parsing for Object Streams
# parsing for Object Streams

# %%
df = pd.DataFrame(results)
df
# Out:
#      identifier                              programa_pdf  programa_pages  \
# 0       4508214                                                       NaN
# 1       4981938                                                       NaN
# 2       5102392  2_4_2021_douma_programa_procedimento.pdf            21.0
# 3       5373973                                                       NaN
# 4       5563634                                                       NaN
# ...         ...                                       ...             ...
# 5676    6832611                                                       NaN
# 5677    6834332                                                       NaN
# 5678    6834454                                                       NaN
# 5679    6846134                                                       NaN
# 5680    6846351                                                       NaN
#
#       programa_match_count                                   caderno_pdf  \
# 0                        0                     1_Caderno_de_Encargos.pdf
# 1                        0                      1_CE_DEGA_ENG_Fisc22.pdf
# 2                        1        1_4_2021_douma_caderno_de_encargos.pdf
# 3                        0              1_Caderno_Encargos_Segurança.pdf
# 4                        0                      1_3_Caderno_Encargos.pdf
# ...                    ...                                           ...
# 5676                     0                        1_Caderno_encargos.pdf
# 5677                     0  1_Caderno_de_Encargos_Eletricidade_final.pdf
# 5678                     0                 1_280_Caderno_de_Encargos.pdf
# 5679                     0  1_P178_2023_Caderno_de_Encargos_ASSINADO.pdf
# 5680                     0
#
#       caderno_pages  caderno_match_count caderno_has_especificacoes_tecnicas
# 0              46.0                    1                                True
# 1             144.0                    1                                True
# 2              23.0                    1                               False
# 3              27.0                    2                               False
# 4              21.0                    1                                True
# ...             ...                  ...                                 ...
# 5676           20.0                    1                               False
# 5677           24.0                    1                                True
# 5678           21.0                    1                                True
# 5679           57.0                    1                                True
# 5680            NaN                    0
#
# [5681 rows x 8 columns]

# %%
df.to_csv("../../data/results_reading_pdfs.csv")
